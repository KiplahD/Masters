# %% [markdown]
# <a href="https://colab.research.google.com/github/KiplahD/Masters/blob/main/Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clustering: Unsupervised Machine Learning where the GOAL is to determine hidden clusters(groups) within the dataset.
# Step1: Read Data
import pandas
data = pandas.read_csv("https://modcom.co.ke/data/datasets/AirlinesCluster.csv")
data
# Out:
#       Balance  QualMiles  BonusMiles  BonusTrans  FlightMiles  FlightTrans  \
# 0       28143          0         174           1            0            0
# 1       19244          0         215           2            0            0
# 2       41354          0        4123           4            0            0
# 3       14776          0         500           1            0            0
# 4       97752          0       43300          26         2077            4
# ...       ...        ...         ...         ...          ...          ...
# 3994    18476          0        8525           4          200            1
# 3995    64385          0         981           5            0            0
# 3996    73597          0       25447           8            0            0
# 3997    54899          0         500           1          500            1
# 3998     3016          0           0           0            0            0
#
#       DaysSinceEnroll
# 0                7000
# ...

# %%
# Grouping Data Into Different Clusters based on Similarities
# E,g Safaricom by grouping their customers based on Calls, sms, bundles
array = data.values
dataValues = array[:, 4:7]
data = pandas.DataFrame(dataValues, columns = ["FlightMiles",	"FlightTrans",	"DaysSinceEnroll"])
data
# Out:
#       FlightMiles  FlightTrans  DaysSinceEnroll
# 0               0            0             7000
# 1               0            0             6968
# 2               0            0             7034
# 3               0            0             6952
# 4            2077            4             6935
# ...           ...          ...              ...
# 3994          200            1             1403
# 3995            0            0             1395
# 3996            0            0             1402
# 3997          500            1             1401
# 3998            0            0             1398
#
# [3999 rows x 3 columns]

# %%
# Split Data Into X
array = data.values
X = array[:, :]
X
# Out:
# array([[   0,    0, 7000],
#        [   0,    0, 6968],
#        [   0,    0, 7034],
#        ...,
#        [   0,    0, 1402],
#        [ 500,    1, 1401],
#        [   0,    0, 1398]])

# %%
# Import KMeans(Group data based on the mean)
from sklearn.cluster import KMeans
model = KMeans(n_clusters=5, random_state=42)
clusters = model.fit(X)
clusters
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=5, random_state=42)

# %%
# Mean Clusters(Centronoids)
means = model.cluster_centers_
groups = pandas.DataFrame(means, columns = ["FlightMiles",	"FlightTrans", 	"DaysSinceEnroll"])
groups
# Out:
#     FlightMiles  FlightTrans  DaysSinceEnroll
# 0    190.490497     0.673977      1852.655702
# 1    289.672694     1.018083      6682.683544
# 2   4303.944785    11.766871      4438.030675
# 3    202.224795     0.702763      4284.259149
# 4  12455.304348    25.478261      3678.956522

# %%
data['Cluster'] = model.labels_

# %%
data
# Out:
#       FlightMiles  FlightTrans  DaysSinceEnroll  Cluster
# 0               0            0             7000        1
# 1               0            0             6968        1
# 2               0            0             7034        1
# 3               0            0             6952        1
# 4            2077            4             6935        1
# ...           ...          ...              ...      ...
# 3994          200            1             1403        0
# 3995            0            0             1395        0
# 3996            0            0             1402        0
# 3997          500            1             1401        0
# 3998            0            0             1398        0
#
# [3999 rows x 4 columns]

# %%
# Getting Members of the Same Clusters
# E,g Cluster 4 Members
cluster_4_members = data[data['Cluster'] == 4]
cluster_4_members
# Out:
#       FlightMiles  FlightTrans  DaysSinceEnroll  Cluster
# 323          9166           16             7155        4
# 531         10250           28             6621        4
# 622         10650           28             6434        4
# 958          9200           28             5916        4
# 1529        12400           29             4996        4
# 1593        12988            9             4848        4
# 1676        10075           36             4708        4
# 1885        16675           18             4076        4
# 1930        10042            4             3925        4
# 2015        22100           45             3831        4
# 2058        11408           23             4331        4
# 2151         9550           20             4008        4
# 2375         9150           26             3530        4
# 2449         8389            9             3259        4
# 2656        10850           26             2511        4
# ...

# %%
cluster_4_members.to_csv("Cluster4.csv")
# Recommender Systems
# NLTK
# Deep Learning
