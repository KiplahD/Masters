# %% [markdown]
# <a href="https://colab.research.google.com/github/KiplahD/Masters/blob/main/Natural_Language_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#NLP is a branch in AI that involves interacting with machines(phone, car, laptop, fridge)
#using a natural language such as text and speech rather than a code.
#Application area: Robotics, ChatBots(zuri, apple siri)
#Data science vs NLP: Analyse text, speech(draw conclusion) e.g sentiment analysis, web scrapping

#Text analysis and wordcloud
#Web scrapping
#Twitter sentiment analysis

#Get text data
text = '''
For weeks, the European Union's stance on the war has been clouded with mixed messages, diplomatic gaffes and conflicting national views on the Israeli-Palestinian conflict.

But after days of disagreement, EU leaders aim to reach a common position.

At issue is whether to back a ceasefire or humanitarian pauses in the fighting.

European Council President Charles Michel says the deteriorating humanitarian situation in Gaza is of grave concern and the leaders are keen to facilitate access to food, water, medical care, fuel and shelter.

They hope that will create safer conditions for the release of more than 200 hostages seized by Hamas gunmen during their 7 October attack. Many of those held captive are European dual nationals, including citizens from Germany, France, Portugal and the Netherlands.

EU member states hold sharply differing views and it all makes for a very confusing picture.

Spain's caretaker prime minister, Pedro Sánchez, wants a humanitarian ceasefire.

But some have reservations about calling for a pause in the fighting and argue it could be seen as limiting Israel's right to self-defence.

Germany and other countries do not support the idea of one, singular humanitarian pause, because that would be too close to the concept of a ceasefire, when Israel has the right to defend itself from attack.

What was needed instead were shorter breaks in the fighting, one diplomat told the BBC. "A pause means both actors stop for good, whereas pauses is temporary. It's short intervals for a few hours, to get aid," they said.

Germany, Austria, Hungary and the Czech Republic have taken strong stances of supporting Israel. Spain and Ireland are more attuned with the Palestinian cause.

Several European leaders have been on a diplomatic tour of the Middle East. Italy's Prime Minister Giorgia Meloni, German Chancellor Olaf Scholz and French President Emmanuel Macron have all had talks with Egypt's President Abdel Fattah El-Sisi.

Austrian Chancellor Karl Nehammer and Czech prime minister Petr Fiala visited Israel on Wednesday.
'''

# %%
#Step 1: import nltk(natural language processing toolkit)
import nltk
nltk.download('punkt')
#used for punctuation toolkit
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
#Convert text to sentences or words
#Tokenization
from nltk.tokenize import sent_tokenize, word_tokenize
tokenized_text = word_tokenize(text)
print (tokenized_text)
# Out:
# ['For', 'weeks', ',', 'the', 'European', 'Union', "'s", 'stance', 'on', 'the', 'war', 'has', 'been', 'clouded', 'with', 'mixed', 'messages', ',', 'diplomatic', 'gaffes', 'and', 'conflicting', 'national', 'views', 'on', 'the', 'Israeli-Palestinian', 'conflict', '.', 'But', 'after', 'days', 'of', 'disagreement', ',', 'EU', 'leaders', 'aim', 'to', 'reach', 'a', 'common', 'position', '.', 'At', 'issue', 'is', 'whether', 'to', 'back', 'a', 'ceasefire', 'or', 'humanitarian', 'pauses', 'in', 'the', 'fighting', '.', 'European', 'Council', 'President', 'Charles', 'Michel', 'says', 'the', 'deteriorating', 'humanitarian', 'situation', 'in', 'Gaza', 'is', 'of', 'grave', 'concern', 'and', 'the', 'leaders', 'are', 'keen', 'to', 'facilitate', 'access', 'to', 'food', ',', 'water', ',', 'medical', 'care', ',', 'fuel', 'and', 'shelter', '.', 'They', 'hope', 'that', 'will', 'create', 'safer', 'conditions', 'for', 'the', 'release', 'of', 'more', 'than', '200', 'hostages', 'seized', 'by', 'Hamas', 'gunmen', 'during', 'their', '7', 'October', 'attack', '.', 'Many', 'of', 'those', 'held', 'captive', 'are', 'European', 'dual', 'nationals', ',', 'including', 'citizens', 'from', 'Germany', ',', 'France', ',', 'Portugal', 'and', 'the', 'Netherlands', '.', 'EU', 'member', 'states', 'hold', 'sharply', 'differing', 'views', 'and', 'it', 'all', 'makes', 'for', 'a', 'very', 'confusing', 'picture', '.', 'Spain', "'s", 'caretaker', 'prime', 'minister', ',', 'Pedro', 'Sánchez', ',', 'wants', 'a', 'humanitarian', 'ceasefire', '.', 'But', 'some', 'have', 'reservations', 'about', 'calling', 'for', 'a', 'pause', 'in', 'the', 'fighting', 'and', 'argue', 'it', 'could', 'be', 'seen', 'as', 'limiting', 'Israel', "'s", 'right', 'to', 'self-defence', '.', 'Germany', 'and', 'other', 'countries', 'do', 'not', 'support', 'the', 'idea', 'of', 'one', ',', 'singular', 'humanitarian', 'pause', ',', 'because', 'that', 'would', 'be', 'too', 'close', 'to', 'the', 'concept', 'of', 'a', 'ceasefire', ',', 'when', 'Israel', 'has', 'the', 'right', 'to', 'defend', 'itself', 'from', 'attack', '.', 'What', 'was', 'needed', 'instead', 'were', 'shorter', 'breaks', 'in', 'the', 'fighting', ',', 'one', 'diplomat', 'told', 'the', 'BBC', '.', '``', 'A', 'pause', 'means', 'both', 'actors', 'stop', 'for', 'good', ',', 'whereas', 'pauses', 'is', 'temporary', '.', 'It', "'s", 'short', 'intervals', 'for', 'a', 'few', 'hours', ',', 'to', 'get', 'aid', ',', "''", 'they', 'said', '.', 'Germany', ',', 'Austria', ',', 'Hungary', 'and', 'the', 'Czech', 'Republic', 'have', 'taken', 'strong', 'stances', 'of', 'supporting', 'Israel', '.', 'Spain', 'and', 'Ireland', 'are', 'more', 'attuned', 'with', 'the', 'Palestinian', 'cause', '.', 'Several', 'European', 'leaders', 'have', 'been', 'on', 'a', 'diplomatic', 'tour', 'of', 'the', 'Middle', 'East', '.', 'Italy', "'s", 'Prime', 'Minister', 'Giorgia', 'Meloni', ',', 'German', 'Chancellor', 'Olaf', 'Scholz', 'and', 'French', 'President', 'Emmanuel', 'Macron', 'have', 'all', 'had', 'talks', 'with', 'Egypt', "'s", 'President', 'Abdel', 'Fattah', 'El-Sisi', '.', 'Austrian', 'Chancellor', 'Karl', 'Nehammer', 'and', 'Czech', 'prime', 'minister', 'Petr', 'Fiala', 'visited', 'Israel', 'on', 'Wednesday', '.']

# %%
#Removing stop words
#Stop words are connecting words in sentences that dont carry meaningful context

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
#Generate the fileids - different languages
from nltk.corpus import  stopwords
print(stopwords.fileids())

english_stopwords = set(stopwords.words('english'))
print(english_stopwords)
# Out:
# ['arabic', 'azerbaijani', 'basque', 'bengali', 'catalan', 'chinese', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hinglish', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'turkish']
# {"it's", 'won', "that'll", 'this', 'is', 'just', 'what', 'if', 'in', 'nor', 'until', 'ain', 'couldn', 'was', 'do', "couldn't", 'weren', 'yourselves', "you'd", 'now', 'other', 'hadn', "isn't", 'after', 'does', 'his', 'against', "you're", 'to', 'on', 'both', 'same', 'all', 'its', "wasn't", 'with', "don't", 'who', 'me', 'will', 'above', 'below', 'most', 'about', "shan't", 'have', 'any', 'are', 'some', 'shouldn', 'itself', 'once', 'again', "won't", "you've", 's', 'has', 'that', "hadn't", 'the', 'these', 'o', 'doesn', 'or', 'm', 'mightn', 'by', 'him', "shouldn't", 'few', 'needn', 'further', 'hasn', 'haven', 'between', 'only', "mustn't", 'them', 'isn', 'wouldn', 'we', 'but', 'over', 'myself', 'her', "aren't", 'so', 'mustn', 'under', 'aren', 'very', 'been', 'there', 'each', 've', "doesn't", "she's", 'not', 'theirs', 'through', "hasn't", "you'll", 'ma', 'while', 'too', 'it', 'they', "mightn't", 'at', 'herself', 'for', 'than', 'were', 'before', 'out', 'here', 're', 'having', 'whom', 'and', "needn't", 'more', 'wasn', 'ours', 'off', 'of', 'yourself', 'did', 'how', 'own', 'your', 'll', 'during', 'should', 'an', 'shan', 'my', 'ourselves', 'which', 'such', 'had', 'don', 'i', "wouldn't", 'he', 'she', 'why', 'where', 'those', 't', "haven't", 'our', 'as', 'themselves', 'because', 'y', "didn't", 'a', 'didn', 'd', 'into', 'when', 'from', 'hers', 'am', 'himself', 'be', 'then', 'can', 'down', 'you', "weren't", 'up', 'yours', 'their', "should've", 'doing', 'no', 'being'}

# %%
#meaningful_words; contains all the words without stopwords
meaningful_words = []
for word in tokenized_text:
  if word.lower() not in english_stopwords:
    meaningful_words.append(word)
print(meaningful_words)
# Out:
# ['weeks', ',', 'European', 'Union', "'s", 'stance', 'war', 'clouded', 'mixed', 'messages', ',', 'diplomatic', 'gaffes', 'conflicting', 'national', 'views', 'Israeli-Palestinian', 'conflict', '.', 'days', 'disagreement', ',', 'EU', 'leaders', 'aim', 'reach', 'common', 'position', '.', 'issue', 'whether', 'back', 'ceasefire', 'humanitarian', 'pauses', 'fighting', '.', 'European', 'Council', 'President', 'Charles', 'Michel', 'says', 'deteriorating', 'humanitarian', 'situation', 'Gaza', 'grave', 'concern', 'leaders', 'keen', 'facilitate', 'access', 'food', ',', 'water', ',', 'medical', 'care', ',', 'fuel', 'shelter', '.', 'hope', 'create', 'safer', 'conditions', 'release', '200', 'hostages', 'seized', 'Hamas', 'gunmen', '7', 'October', 'attack', '.', 'Many', 'held', 'captive', 'European', 'dual', 'nationals', ',', 'including', 'citizens', 'Germany', ',', 'France', ',', 'Portugal', 'Netherlands', '.', 'EU', 'member', 'states', 'hold', 'sharply', 'differing', 'views', 'makes', 'confusing', 'picture', '.', 'Spain', "'s", 'caretaker', 'prime', 'minister', ',', 'Pedro', 'Sánchez', ',', 'wants', 'humanitarian', 'ceasefire', '.', 'reservations', 'calling', 'pause', 'fighting', 'argue', 'could', 'seen', 'limiting', 'Israel', "'s", 'right', 'self-defence', '.', 'Germany', 'countries', 'support', 'idea', 'one', ',', 'singular', 'humanitarian', 'pause', ',', 'would', 'close', 'concept', 'ceasefire', ',', 'Israel', 'right', 'defend', 'attack', '.', 'needed', 'instead', 'shorter', 'breaks', 'fighting', ',', 'one', 'diplomat', 'told', 'BBC', '.', '``', 'pause', 'means', 'actors', 'stop', 'good', ',', 'whereas', 'pauses', 'temporary', '.', "'s", 'short', 'intervals', 'hours', ',', 'get', 'aid', ',', "''", 'said', '.', 'Germany', ',', 'Austria', ',', 'Hungary', 'Czech', 'Republic', 'taken', 'strong', 'stances', 'supporting', 'Israel', '.', 'Spain', 'Ireland', 'attuned', 'Palestinian', 'cause', '.', 'Several', 'European', 'leaders', 'diplomatic', 'tour', 'Middle', 'East', '.', 'Italy', "'s", 'Prime', 'Minister', 'Giorgia', 'Meloni', ',', 'German', 'Chancellor', 'Olaf', 'Scholz', 'French', 'President', 'Emmanuel', 'Macron', 'talks', 'Egypt', "'s", 'President', 'Abdel', 'Fattah', 'El-Sisi', '.', 'Austrian', 'Chancellor', 'Karl', 'Nehammer', 'Czech', 'prime', 'minister', 'Petr', 'Fiala', 'visited', 'Israel', 'Wednesday', '.']

# %%
#Removing punctuations: clean the words
clean_words = []
for word in meaningful_words:
  if word.isalpha():
    clean_words.append(word)
print(clean_words)
# Out:
# ['weeks', 'European', 'Union', 'stance', 'war', 'clouded', 'mixed', 'messages', 'diplomatic', 'gaffes', 'conflicting', 'national', 'views', 'conflict', 'days', 'disagreement', 'EU', 'leaders', 'aim', 'reach', 'common', 'position', 'issue', 'whether', 'back', 'ceasefire', 'humanitarian', 'pauses', 'fighting', 'European', 'Council', 'President', 'Charles', 'Michel', 'says', 'deteriorating', 'humanitarian', 'situation', 'Gaza', 'grave', 'concern', 'leaders', 'keen', 'facilitate', 'access', 'food', 'water', 'medical', 'care', 'fuel', 'shelter', 'hope', 'create', 'safer', 'conditions', 'release', 'hostages', 'seized', 'Hamas', 'gunmen', 'October', 'attack', 'Many', 'held', 'captive', 'European', 'dual', 'nationals', 'including', 'citizens', 'Germany', 'France', 'Portugal', 'Netherlands', 'EU', 'member', 'states', 'hold', 'sharply', 'differing', 'views', 'makes', 'confusing', 'picture', 'Spain', 'caretaker', 'prime', 'minister', 'Pedro', 'Sánchez', 'wants', 'humanitarian', 'ceasefire', 'reservations', 'calling', 'pause', 'fighting', 'argue', 'could', 'seen', 'limiting', 'Israel', 'right', 'Germany', 'countries', 'support', 'idea', 'one', 'singular', 'humanitarian', 'pause', 'would', 'close', 'concept', 'ceasefire', 'Israel', 'right', 'defend', 'attack', 'needed', 'instead', 'shorter', 'breaks', 'fighting', 'one', 'diplomat', 'told', 'BBC', 'pause', 'means', 'actors', 'stop', 'good', 'whereas', 'pauses', 'temporary', 'short', 'intervals', 'hours', 'get', 'aid', 'said', 'Germany', 'Austria', 'Hungary', 'Czech', 'Republic', 'taken', 'strong', 'stances', 'supporting', 'Israel', 'Spain', 'Ireland', 'attuned', 'Palestinian', 'cause', 'Several', 'European', 'leaders', 'diplomatic', 'tour', 'Middle', 'East', 'Italy', 'Prime', 'Minister', 'Giorgia', 'Meloni', 'German', 'Chancellor', 'Olaf', 'Scholz', 'French', 'President', 'Emmanuel', 'Macron', 'talks', 'Egypt', 'President', 'Abdel', 'Fattah', 'Austrian', 'Chancellor', 'Karl', 'Nehammer', 'Czech', 'prime', 'minister', 'Petr', 'Fiala', 'visited', 'Israel', 'Wednesday']

# %%
#Frequency Distribution:
from nltk.probability import FreqDist
frequency_count= FreqDist(clean_words)
frequency_count.most_common(20)
# Out:
# [('European', 4),
#  ('humanitarian', 4),
#  ('Israel', 4),
#  ('leaders', 3),
#  ('ceasefire', 3),
#  ('fighting', 3),
#  ('President', 3),
#  ('Germany', 3),
#  ('pause', 3),
#  ('diplomatic', 2),
#  ('views', 2),
#  ('EU', 2),
#  ('pauses', 2),
#  ('attack', 2),
#  ('Spain', 2),
#  ('prime', 2),
#  ('minister', 2),
#  ('right', 2),
#  ('one', 2),
#  ('Czech', 2)]

# %%
#Visualize the FreqDist on wordcloud
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

#generate  a function  to generate WordCloud
def generate_wordcloud(text):
  stopwords = set(STOPWORDS)
  wc = WordCloud(background_color= "white", max_words=1000, stopwords=stopwords, repeat=True)
  wc.generate(str(text))
  wc.to_file("wc.png")
  path = "wc.png"
  display(Image.open(path))
generate_wordcloud(frequency_count.most_common(20))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=400x200>
