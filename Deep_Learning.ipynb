# %% [markdown]
# <a href="https://colab.research.google.com/github/KiplahD/Masters/blob/main/Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Artificial Neural Network -> ANN
# Human Neural Network -

# Machine Learning: We Train Machine to Learn from Data.(Scientific)
# Deep Learning: ANN to learn from other sources, images, videos, speech...(ANN)

# Create a machine the can predict patients with TuberCloasis, Pnemonia, Covid, Cancer(Xray Images)
# Create a machine to predict Traffic Rule Violations(videos)

# %%
# Simple Deep Model:
# Regression

import pandas
data = pandas.read_csv("Advertising.csv")
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
# Prediction - Supervised Learning
# Divide X and Y
array = data.values

X = array[:, 0:3]
Y = array[:, 3]

# %%
# Split Data into Training Set and Testing Set
from sklearn import model_selection
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
# How is the Learning?
# ML - applied scientific algoriths e,g DecisionTree, KNeighbors....
# DL - Construct an Artificial Neural Network - keras

# %%
# ANN Features: Sequential, Dense, Dropout, Flatten, activation function
from keras.models import Sequential
from keras.layers import Dense, Dropout
import keras

# %%
# Used to generate sequence of nodes(neurons)
model = Sequential()

# %%
# Create the Layers using Dense

# Read more: relu, softmax, sigmoid activation functions
model.add(Dense(500, input_dim = 3, activation = "relu"))

model.add(Dense(100, activation = "relu"))

model.add(Dense(50, activation = "relu"))


# Output Layer
model.add(Dense(1, activation = "sigmoid"))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# # Install ann_visualizer
# !pip3 install ann_visualizer

# %%
# # Visualize the Network
# from ann_visualizer.visualize import ann_viz
# ann_viz(model, view = True, title = "Sales Regression ANN Network", filename='ann.gv')

# %%
# Adding Data to the Dense Layer
# Activation Functions
# Training the Model(epochs...)
# Model Evaluation.
# Image Classification(Recognision)

# %%
# Visualizing the ANN Model
from keras.utils import plot_model
plot_model(model, to_file = 'ann.png', show_shapes = True)
