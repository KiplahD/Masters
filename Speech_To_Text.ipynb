# %% [markdown]
# <a href="https://colab.research.google.com/github/KiplahD/Masters/blob/main/Speech_To_Text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Speech recognition
#Pre-Trained Model
#Hugging face:  AI company of building pre-trained models

# !pip install gTTS
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 2.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.2.1
#     Uninstalling click-8.2.1:
#       Successfully uninstalled click-8.2.1
# ...

# %%
from gtts import gTTS

myText = "Python is commonly used for developing websites and software, task automation, data analysis, and data visualisation. Since it's relatively easy to learn, Python has been adopted by many non-programmers, such as accountants and scientists, for a variety of everyday tasks, like organising finances."
language= 'en'

# %%
speech = gTTS(text = myText, lang = language, slow = False)
speech.save("speech.mp3")

# %%
from IPython.display import Audio
from IPython.display import display
sound_file = 'speech.mp3'
sound = Audio(sound_file, autoplay = True)
display(sound)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#speech to text
# !pip install transformers

# %%
#manage audio - librosa
import librosa

# %%
#Audio Processing -torch
import torch

# %%
#Pre-trained (Speech to text)- hugging face
from transformers import Wav2Vec2ForCTC, Wav2Vec2Tokenizer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Pre-process the audio with Librosa
#sr - 16000
audio, rate = librosa.load('speech.mp3', sr = 16000)

# %%
#Tokenize audio file and feed it to the model
tokenizer = Wav2Vec2Tokenizer.from_pretrained("facebook/Wav2Vec2-base-960h")
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'Wav2Vec2CTCTokenizer'.
# The class this function is called from is 'Wav2Vec2Tokenizer'.
# /usr/local/lib/python3.11/dist-packages/transformers/models/wav2vec2/tokenization_wav2vec2.py:720: FutureWarning: The class `Wav2Vec2Tokenizer` is deprecated and will be removed in version 5 of Transformers. Please use `Wav2Vec2Processor` or `Wav2Vec2CTCTokenizer` instead.
#   warnings.warn(

# %%
model = Wav2Vec2ForCTC.from_pretrained("facebook/Wav2Vec2-base-960h")
# Out:
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/Wav2Vec2-base-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
input_tokenize= tokenizer(audio, return_tensors = "pt").input_values

# %%
import torch
import torchaudio
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor

# Load pretrained model and processor
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-base-960h")
model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")

# Load audio file
audio_file = "speech.mp3"
waveform, rate = torchaudio.load(audio_file)  # waveform: [1, num_samples]

# Resample if needed (Wav2Vec2 expects 16kHz)
if rate != 16000:
    resampler = torchaudio.transforms.Resample(orig_freq=rate, new_freq=16000)
    waveform = resampler(waveform)
    rate = 16000

# Process input and run through model
input_values = processor(waveform.squeeze(), return_tensors="pt", sampling_rate=rate).input_values
with torch.no_grad():
    logits = model(input_values).logits

# Get predicted token IDs
predicted_ids = torch.argmax(logits, dim=-1)

# Decode IDs to text
transcription = processor.decode(predicted_ids[0])
print("Transcription:", transcription)
# Out:
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Transcription: PYTHON IS COMMONLY USED FOR DEVELOPING WEBSITES AND SOFTWARE TASK AUTOMATION DATA ANALYSIS ANDATA VISUALIZATION SINCE IT'S RELATIVELY EASY TO LEARN PYTHON HAS BEEN ADOPTED BY MANY NON PROGRAMMERS SUCH AS A COUNTENCE AND SCIENTISTS FOR A VARIETY OF EVERYDAY TASKS LIKE ORGANIZING FINANCES
